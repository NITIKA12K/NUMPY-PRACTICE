# %% [markdown]
# <a href="https://colab.research.google.com/github/NITIKA12K/NUMPY-PRACTICE/blob/main/MY_PANDAS_SERIyS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTING PANDAS**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Series from lists**

# %%
#string
country=["india",'pakistan','newyork','malaysia']
pd.Series(country)           # CAPITAL S
# Out:
# 0       india
# 1    pakistan
# 2     newyork
# 3    malaysia
# dtype: object

# %%
#integers
runs=[87,88,00,22,22]
runs_ser=pd.Series(runs)

# %%
#custom index + #Setting a name
marks=[89,67,45,78,98]
subjects=['maths','hindi','english','DBMS','GMGJ']
marks=pd.Series(marks,index=subjects,name='nitika ke marks')
marks
# Out:
# maths      89
# hindi      67
# english    45
# DBMS       78
# GMGJ       98
# Name: nitika ke marks, dtype: int64

# %% [markdown]
# # **Series from dict**

# %%
marks={                               #in dictonary you don't have to mention that this is  your index
    'english':56,
    'maths' :88,
    'hghjgj' :77,
    'oopws':88
}
marks_series=pd.Series(marks,name='nitika ke marks')
marks_series
# Out:
# english    56
# maths      88
# hghjgj     77
# oopws      88
# Name: nitika ke marks, dtype: int64

# %% [markdown]
# # **Series Attributes**

# %%
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'nitika ke marks'

# %%
#is_unique
marks_series.is_unique
# Out:
# False

# %%
pd.Series([1,11,2,1,1]).is_unique
# Out:
# False

# %%
#index
marks_series.index
# Out:
# Index(['english', 'maths', 'hghjgj', 'oopws'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#values
marks_series.values         #it means it give array numpy array
# Out:
# array([56, 88, 77, 88])

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %% [markdown]
# # **Series using read_csv**

# %%
#with one colmn
subs=pd.read_csv('/content/subs.csv').squeeze("columns")
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#with 2 cols
vk=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies=pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze("columns")
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
#head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#sample
movies.sample()
# Out:
# movie
# Motu Patlu: King of Kings    Saurav Chakraborty
# Name: lead, dtype: object

# %%
#value_counts
movies.value_counts()            #tell all the counts of every lead actor
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
movies.value_counts()['Akshay Kumar']
# Out:
# np.int64(48)

# %%
#sort values->inplace
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
vk=vk.copy()
vk.sort_values(inplace=True)

# %%
vk=vk.sort_values()

# %%
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
#sort_index->inplace -> movies
movies.sort_index(inplace=True)

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## **SERIES MATHS METHODS**

# %%
#count   dont include missing values
vk.count()
# Out:
# np.int64(215)

# %%
#sum ->product
subs.sum()
# Out:
# np.int64(49510)

# %%
subs.prod()
# Out:
# np.int64(0)

# %%
#mean->median->mode->std->var
subs.mean()
print(movies.mode())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
#min/max
subs.min()
# Out:
# 33

# %% [markdown]
# Let's check if there are any zero values in the `subs` Series to confirm this.

# %%
print((subs == 0).any())
print(subs[subs == 0])
# Out:
# False
# Series([], Name: Subscribers gained, dtype: int64)

# %% [markdown]
# To illustrate the concept of integer overflow, let's try calculating the product using `float64` which can handle much larger numbers (though with floating-point precision).

# %%
# Calculate the product after converting to float64 to avoid integer overflow
print(subs.astype(float).prod())
# Out:
# inf
# /usr/local/lib/python3.13/dist-packages/numpy/_core/_methods.py:57: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims, initial, where)

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# # **SERIES INDEXING**

# %%
#INTEGER indexing (normal index)
x=pd.Series([12,34,56,77,88,9,8])
x
# Out:
# 0    12
# 1    34
# 2    56
# 3    77
# 4    88
# 5     9
# 6     8
# dtype: int64

# %%
x[0]
# Out:
# np.int64(12)

# %%
movies[0]
# Out:
# /tmp/ipykernel_606/3901301928.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[0]
# 'Rajniesh Duggall'

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies['Zor Lagaa Ke...Haiya!']     #indexing with labels
# Out:
# 'Meghan Jadhav'

# %%
movies[-1]
# Out:
# /tmp/ipykernel_606/2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Meghan Jadhav'

# %%
#slicing
vk[1:11]
# Out:
# match_no
# 87     0
# 93     0
# 91     0
# 206    0
# 207    0
# 135    0
# 130    0
# 211    0
# 106    1
# 204    1
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
#fancy indexing
vk[[2,34,5,6]]
# Out:
# match_no
# 2     23
# 34    58
# 5      1
# 6      9
# Name: runs, dtype: int64

# %% [markdown]
# **Series with python functionalities**

# %%
#len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(sorted(subs))
print(dir(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(marks_series)
# Out:
# [56, 88, 77, 88]

# %%
#membership operators     (only deal with index)
movies
'1971 (2007 film)'in movies
# Out:
# True

# %%
#looping
for i in movies.index:
  print(i)
# Out:
# 1920 (film)
# 1920: London
# 1920: The Evil Returns
# 1971 (2007 film)
# 2 States (2014 film)
# 22 Yards
# 3 A.M. (2014 film)
# 3 Deewarein
# 3 Idiots
# 3 Storeys
# 31st October (film)
# 36 China Town
# 3G (film)
# 404 (film)
# 5 Weddings
# 68 Pages
# 7 Hours to Go
# 7 Khoon Maaf
# 7½ Phere
# 88 Antop Hill
# 99 (2009 film)
# 99.9 FM (film)
# ?: A Question Mark
# A Decent Arrangement
# A Flat (film)
# A Flying Jatt
# A Gentleman
# ABCD 2
# Aa Dekhen Zara
# Aa Gaya Hero
# Aabra Ka Daabra
# Aag (2007 film)
# Aagey Se Right
# Aaj Ka Andha Kanoon
# Aaja Nachle
# Aakhari Decision
# Aakrosh (2010 film)
# Aalaap (film)
# Aan: Men at Work
# Aanch
# Aankhen (2002 film)
# Aap Kaa Surroor
# Aap Ki Khatir (2006 film)
# Aapko Pehle Bhi Kahin Dekha Hai
# Aarakshan
# Aashayein
# Aashiq Banaya Aapne
# Aashiqui 2
# Aashiqui.in
# Aasma: The Sky Is the Limit
# Aazaan
# Ab Tak Chhappan 2
# Ab Tumhare Hawale Watan Saathiyo
# Accident on Hill Road
# Acid Factory
# Action Jackson (2014 film)
# ...

# %%
#Arithmetic operators(Broadcasting)
100+ marks_series
# Out:
# english    156
# maths      188
# hghjgj     177
# oopws      188
# Name: nitika ke marks, dtype: int64

# %%
#Relational operators
vk>=50
# Out:
# match_no
# 8      False
# 87     False
# 93     False
# 91     False
# 206    False
#        ...
# 164     True
# 120     True
# 123     True
# 126     True
# 128     True
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# **Boolean indexing on series**

# %%
#find no of 50's and 100's scored by kohli.
vk[vk>=50]
# Out:
# match_no
# 15      50
# 182     50
# 197     51
# 71      51
# 103     51
# 122     52
# 198     53
# 131     54
# 129     54
# 137     55
# 44      56
# 85      56
# 144     57
# 57      57
# 80      57
# 34      58
# 209     58
# 141     58
# 73      58
# 104     62
# 132     62
# 134     64
# 74      65
# 45      67
# 162     67
# 97      67
# 148     68
# 52      70
# 152     70
# 41      71
# 175     72
# 188     72
# 68      73
# 213     73
# 99      73
# 127     75
# 116     75
# 117     79
# 119     80
# 110     82
# 160     84
# 178     90
# 145     92
# 81      93
# 82      99
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, dtype: int64

# %%
vk[(vk > 50) & (vk < 100)]  #if we want more than 50 but less than 100
# Out:
# match_no
# 197    51
# 71     51
# 103    51
# 122    52
# 198    53
# 131    54
# 129    54
# 137    55
# 44     56
# 85     56
# 144    57
# 57     57
# 80     57
# 34     58
# 209    58
# 141    58
# 73     58
# 104    62
# 132    62
# 134    64
# 74     65
# 45     67
# 162    67
# 97     67
# 148    68
# 52     70
# 152    70
# 41     71
# 175    72
# 188    72
# 68     73
# 213    73
# 99     73
# 127    75
# 116    75
# 117    79
# 119    80
# 110    82
# 160    84
# 178    90
# 145    92
# 81     93
# 82     99
# Name: runs, dtype: int64

# %%
#find actors who have done more than 20 movies
num_movies=movies.value_counts()
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# **Plotting Graphs on series**

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %% [markdown]
# **SOME IMPORTANT SERIES METHOD**

# %%
#astype
#between
#clip
#drop duplicates
#isnull
#dropna
#fillna
#isin
#apply
#copy

# %%
#astype
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
import sys
sys.getsizeof(vk.astype('int16'))
# Out:
# 10478

# %%
#between
vk[vk.between(51,99)].size      #boolean->index with value ->size
# Out:
# 43

# %%
#clip
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#drop_duplicates
temp=pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(934)

# %%
movies.size
# Out:
# 1500

# %%
temp=pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
#isnull
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
#dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(temp.mean())                 #you can put any value inside this fillna bracket like 0 etc
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
#isin
vk[(vk==33)|(vk==47)]              #if we will write like this we have to write long things
# Out:
# match_no
# 186    33
# 181    33
# 185    33
# 118    33
# Name: runs, dtype: int64

# %%
# isin            this method solve the problem
vk[vk.isin([33,54,52])]
# Out:
# match_no
# 186    33
# 181    33
# 185    33
# 118    33
# 122    52
# 131    54
# 129    54
# Name: runs, dtype: int64

# %%
#apply
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# 1920 (film)                 RAJNIESH
# 1920: London                 SHARMAN
# 1920: The Evil Returns         VICKY
# 1971 (2007 film)               MANOJ
# 2 States (2014 film)           ARJUN
#                               ...
# Zindagi 50-50                  VEENA
# Zindagi Na Milegi Dobara     HRITHIK
# Zindagi Tere Naam             MITHUN
# Zokkomon                    DARSHEEL
# Zor Lagaa Ke...Haiya!         MEGHAN
# Name: lead, Length: 1500, dtype: object

# %%
subs.apply(lambda x:'good day' if x>subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
#copy
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
new=vk.head()
#head function automatically create copy so we not need compulsory to make copy

# %%
new
# Out:
# match_no
# 8      0
# 87     0
# 93     0
# 91     0
# 206    0
# Name: runs, dtype: int64

# %%
new[1]=1

# %%
new
#here you can see it create a new index of 1 with value 1 as it not found any index as 1 it do like this because it think that we do label positioning.
# Out:
# match_no
# 8      0
# 87     0
# 93     0
# 91     0
# 206    0
# 1      1
# Name: runs, dtype: int64

# %%
new.iloc[1]=1
#in this we intendfully do index positioning

# %%
new
# Out:
# match_no
# 8      0
# 87     1
# 93     0
# 91     0
# 206    0
# 1      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
new=vk.head().copy()    #after creating copy also all is same as above
new[1]=100
new
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
# 1      100
# Name: runs, dtype: int64
